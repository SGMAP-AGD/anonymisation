# %%
import csv
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

from anonymizer.import_insee import (expand_insee,
                                     nbre_modif)

from anonymizer.anonymity import (get_k, get_anonymities,
                                  less_anonym_groups,
                                  local_aggregation,
                                  _local_aggregate_one_var)
from anonymizer.diversity import (get_l,
                                  get_diversities,
                                  diversity_distribution,
                                  less_diverse_groups
                                )
from anonymizer.transformations import (first_letters,
                                       last_letters)
from anonymizer.transformations import str_drop
from anonymizer.anonymDF import AnonymDataFrame

# %%
chemin = "/home/pierre-louis/Téléchargements/Equides.csv"

equides = pd.read_csv(chemin, sep = ";", encoding = "ISO-8859-1", nrows = 50000, header=None, low_memory = False)

# %%
nom_de_colonnes = ['Race',
                   'Sexe',
                   'Robe',
                   'Date de naissance',
                   'Pays de naissance',
                   'Nom',
                   'Destiné à la consommation humaine',
                   'Date de mort']

# %%
equides.columns = nom_de_colonnes

# %%
variables_supprimees = ['Date de mort']

equides = equides.drop(variables_supprimees,1)

# %%
equides['Date de naissance'] = last_letters(equides['Date de naissance'],6)
equides = equides.fillna('non renseigné')
equides = equides.applymap(lambda x: x.strip())
equides.replace('', 'non renseigné', inplace=True)

# %%
equides
# Out:
#                   Race Sexe                Robe Date de naissance  \
# 0         OR. INCONNUE    H                 BAI     non renseigné
# 1         OR. INCONNUE    H                 BAI     non renseigné
# 2                PONEY    H            ISABELLE     non renseigné
# 3          ARABE-BARBE    M        GRIS ROUANNE     non renseigné
# 4         OR. INCONNUE    M             PIE BAI     non renseigné
# 5         OR. INCONNUE    M                 BAI     non renseigné
# 6         OR. INCONNUE    H      BAI BRUN FONCE     non renseigné
# 7         OR. INCONNUE    H          PIE ALEZAN     non renseigné
# 8         OR. INCONNUE    H          PIE ALEZAN     non renseigné
# 9      KON. WARMB. NED    H           BAI FONCE              1987
# 10         OLDENBURGER    H                GRIS              1986
# 11     PONEY HAFLINGER    H  ALEZAN CRINS LAVES              1974
# 12            PUR SANG    H                 BAI              1982
# 13            PUR SANG    H                 BAI              1984
# 14      SELLE ETRANGER    H                 BAI              1983
# 15        HESSEN HORSE    H              ALEZAN              1984
# 16      SELLE ETRANGER    H                 BAI              1980
# 17     KON. WARMB. NED    H                GRIS              1983
# 18            IRISH SH    H                 BAI     non renseigné
# 19            IRISH SH    H              ALEZAN     non renseigné
# 20     KON. WARMB. NED    H              ALEZAN              1984
# 21      SELLE ETRANGER    H              ALEZAN              1983
# 22      SELLE ETRANGER    H                 BAI              1981
# 23           WESTF. RH    H                 BAI              1983
# 24     KON. WARMB. NED    H                 BAI              1985
# 25            PUR SANG    H           BAI FONCE              1984
# 26      BELGIAN WARMB.    H                 BAI              1979
# 27               BARBE    M        GRIS ROUANNE     non renseigné
# 28        OR. INCONNUE    M                GRIS     non renseigné
# 29        OR. INCONNUE    H             PIE BAI     non renseigné
# ...                ...  ...                 ...               ...
# 24             PAYS-BAS              DUBAI                     non renseigné
# 25              IRLANDE      BERT THE BEST                     non renseigné
# 26             BELGIQUE          CRAZY BOY                     non renseigné
# 27        non renseigné             MOULAY                     non renseigné
# 28        non renseigné            UTAMARO                     non renseigné
# 29        non renseigné             ZEPHIR                     non renseigné
# ...                 ...                ...                               ...
# 49970     non renseigné       VELIKI LOUKI                     non renseigné
# 49971     non renseigné             NAROVA                     non renseigné
# 49972     non renseigné           TURRESIA                     non renseigné
# 49973     non renseigné        LA REINE II                     non renseigné
# 49974     non renseigné            ANONYME                     non renseigné
# 49975     non renseigné             SOANDA                     non renseigné
# 49976     non renseigné             MUFFIN                     non renseigné
# 49977     non renseigné           MOUSSICA                     non renseigné
# 49978           IRLANDE          ANNALECKA                     non renseigné
# 49979     non renseigné        MALEDICTION                     non renseigné
# 49980     non renseigné          CALENDULA                     non renseigné
# 49981   GRANDE-BRETAGNE            CHAITRA                     non renseigné
# 49982     non renseigné           JAVA SEA                     non renseigné
# 49983   GRANDE-BRETAGNE         DIORISSIMA                     non renseigné
# 49984   GRANDE-BRETAGNE       NEVER A FEAR                     non renseigné
# 49985     non renseigné        POLYNICE II                     non renseigné
# 49986     non renseigné   REINE DE LA NUIT                     non renseigné
# 49987     non renseigné         LA FURIOSE                     non renseigné
# 49988        ETATS UNIS    FASHION VERDICT                     non renseigné
# 49989     non renseigné              CAIDA                     non renseigné
# 49990           IRLANDE       TORY VICTORY                     non renseigné
# 49991     non renseigné        LOTTA MILES                     non renseigné
# 49992     non renseigné      STONE'S THROW                     non renseigné
# 49993     non renseigné       BRIEF CANDLE                     non renseigné
# 49994     non renseigné           GLENTIES                     non renseigné
# 49995     non renseigné           TIMAKOWA                     non renseigné
# 49996     non renseigné      FEE PRINTEMPS                     non renseigné
# 49997     non renseigné           SAMELINE                     non renseigné
# 49998     non renseigné              VILNA                     non renseigné
# 49999     non renseigné            MELAIKA                     non renseigné
#
# [50000 rows x 7 columns]

# %%
less_anonym_groups(equides, var)
equides.Race.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6c830f6797c6> in <module>()
# ----> 1 less_anonym_groups(equides, var)
#       2 equides.Race.value_counts()
#
# NameError: name 'var' is not defined

# %%
var = ['Race',                  'Robe'   ]

# %%
var = ['Race',                  'Robe',
                   'Date de naissance',
                   'Pays de naissance',
                   'Destiné à la consommation humaine']
k = 5
equides_kanonym = local_aggregation(equides.copy(), k, var, method='regroup')

# %%
equides['Date de naissance'].replace('non renseigné', 0, inplace = True)
equides['Date de naissance'] = equides['Date de naissance'].astype(int)
equides['Date de naissance'].replace(0, np.nan, inplace = True)

# %%
type(equides['Date de naissance'])
# Out:
# pandas.core.series.Series

# %%
changement_date(equides, 5, ['Date de naissance'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-48cff901857d> in <module>()
# ----> 1 changement_date(equides, 5, ['Date de naissance'])
#
# <ipython-input-18-0087b85317a8> in changement_date(tab, k, var)
#       7         valeur_non_renseignée = 9999
#       8         serie2.replace('non renseigné', valeur_non_renseignée, inplace = True)
# ----> 9         serie2 = serie2.astype(int)
#      10
#      11         counts = serie2.value_counts()
#
# /home/pierre-louis/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in astype(self, dtype, copy, raise_on_error, **kwargs)
#    2948
#    2949         mgr = self._data.astype(dtype=dtype, copy=copy,
# -> 2950                                 raise_on_error=raise_on_error, **kwargs)
#    2951         return self._constructor(mgr).__finalize__(self)
#    2952
#
# /home/pierre-louis/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    2936
#    2937     def astype(self, dtype, **kwargs):
# -> 2938         return self.apply('astype', dtype=dtype, **kwargs)
#    2939
#    2940     def convert(self, **kwargs):
#
# /home/pierre-louis/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, raw, **kwargs)
#    2888
#    2889             kwargs['mgr'] = self
# -> 2890             applied = getattr(b, f)(**kwargs)
#    2891             result_blocks = _extend_blocks(applied, result_blocks)
#    2892
#
# /home/pierre-louis/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in astype(self, dtype, copy, raise_on_error, values, **kwargs)
#     432                **kwargs):
#     433         return self._astype(dtype, copy=copy, raise_on_error=raise_on_error,
# --> 434                             values=values, **kwargs)
#     435
#     436     def _astype(self, dtype, copy=False, raise_on_error=True, values=None,
#
# /home/pierre-louis/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, raise_on_error, values, klass, mgr, **kwargs)
#     475
#     476                 # _astype_nansafe works fine with 1-d only
# --> 477                 values = com._astype_nansafe(values.ravel(), dtype, copy=True)
#     478                 values = values.reshape(self.shape)
#     479
#
# /home/pierre-louis/anaconda3/lib/python3.5/site-packages/pandas/core/common.py in _astype_nansafe(arr, dtype, copy)
#    1915     elif arr.dtype == np.object_ and np.issubdtype(dtype.type, np.integer):
#    1916         # work around NumPy brokenness, #1987
# -> 1917         return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1918
#    1919     if copy:
#
# pandas/lib.pyx in pandas.lib.astype_intsafe (pandas/lib.c:16667)()
#
# pandas/src/util.pxd in util.set_value_at (pandas/lib.c:65414)()
#
# ValueError: invalid literal for int() with base 10: '1961 ou 1960'

# %%
def changement_date(serie, k, var) :
    serie1 = serie.copy()
    serie2 = serie.copy()
    valeur_non_renseignée = 9999
    serie2.replace('non renseigné', valeur_non_renseignée, inplace = True)
    serie2 = serie2.astype(int)
    
    counts = serie2.value_counts()
    counts_to_change = counts[counts < k]
    index_to_change = counts_to_change.index.tolist()
    liste_a_comparer = serie2.unique().tolist()
    minimums = []
    
    for valeur_à_remplacer in index_to_change : 
        if valeur_à_remplacer not in minimums : 
            liste_a_comparer2 = liste_a_comparer
            liste_a_comparer2.remove(valeur_à_remplacer)
            pour_regrouper = [str(valeur_à_remplacer)]

            d = {}
            for i in liste_a_comparer2 :
                d[i] = abs(i - valeur_à_remplacer)
            minimum = min(d.items(), key = lambda x: x[1])

            for k in serie1.unique().tolist():
                if str(minimum[0]) in k :
                    pour_regrouper.append(k)

            new_name = ' ou '.join(pour_regrouper)
            serie1 = serie1.replace(pour_regrouper, new_name)
            minimums.append(minimum[0])
    
    return serie1

# %%
serie = local_aggregation(equides, 2, ['Date de naissance'], method = "year")

# %%
serie['Date de naissance'].value_counts()
# Out:
# non renseigné    39301
# 1990              1411
# 1991              1345
# 1988              1209
# 1987               947
# 1986               875
# 1989               873
# 1992               854
# 1984               834
# 1985               800
# 1983               448
# 1982               233
# 1993               212
# 1981               161
# 1980               102
# 1979                69
# 1978                58
# 1976                41
# 1977                38
# 1994                37
# 1973                25
# 1974                21
# 1972                19
# 1975                16
# 1971                 7
# 2005 ou 2004         5
# 1959 ou 1958         5
# 1957 ou 1956         4
# 1962                 4
# 1961 ou 1960         4
# 2008                 4
# 1996 ou 1995         3
# 1965                 3
# 1967                 3
# 1951                 3
# 1970                 3
# 1968                 3
# 2006 ou 2007         3
# 1939 ou 1945         3
# 1954 ou 1953         2
# 1947                 2
# 1964                 2
# 1955                 2
# 2012 ou 2009         2
# 2000 ou 2003         2
# 1949                 2
# Name: Date de naissance, dtype: int64

# %%
j = 'lalala ou lalala'.split()

# %%
for poez in j :
    print(poez)

# %%
for valeur_à_remplacer in str(index_to_change) : # on sélectionne une variable à remplacer
    if valeur_à_remplacer in serie.unique():
        serie2 = serie.copy()
        valeur_non_renseignee = - 9999
        serie2.replace('non renseigné', valeur_non_renseignee, inplace = True)
        counts = serie2.value_counts()
        counts_to_change = counts[counts < 5]
        index_to_change = counts_to_change.index.tolist()
        liste_a_comparer = serie2.unique().tolist()
        liste_a_comparer = [str(i) for i in liste_a_comparer]
        d = {}    
        annee = []
        for i in liste_a_comparer :
            if 'ou' in i :
                annee = i.split()
                annee = [item for item in annee if item != 'ou']
                liste_a_comparer.remove(i)
                liste_a_comparer = liste_a_comparer + annee
        if valeur_à_remplacer in liste_a_comparer :
            liste_a_comparer = [item for item in liste_a_comparer if item != valeur_à_remplacer]
        liste_a_comparer = [int(i) for i in liste_a_comparer]
        
        pour_regrouper = [str(valeur_à_remplacer)]

        for i in liste_a_comparer :
            d[i] = abs(i - valeur_à_remplacer)
        minimum = min(d.items(), key = lambda x: x[1])
        if str(minimum[0]) in annee : 
            pour_regrouper = pour_regrouper + annee
        else :
            pour_regrouper.append(str(minimum[0]))
        new_name = ' ou '.join(pour_regrouper)
        serie = serie.replace(pour_regrouper, new_name)

# %%
serie.value_counts()

# %%
liste_a_comparer

# %%
annee

# %%
ou

# %%
serie[1987].counts()

# %%
minimum = min(d.items(), key = lambda x: x[1])

# %%
pour_regrouper = [minimum[0]]

# %%
pour_regrouper.append(counts_to_change.index[0])

# %%
pour_regrouper

# %%
serie.replace(counts_to_change.index[0], pour_regrouper)

# %%
list_date_mort = equides['Date de mort'].unique().tolist()

# %%
for row in pd.to_datetime(equides['Date de naissance'], infer_datetime_format=True):
    annee.append(row.year)
    mois.append(row.month)

# %%
l = pd.to_datetime(equides['Date de naissance'][equides['Date de naissance'] != 'non renseigné'], infer_datetime_format=True)

# %%
equides['date'] = l

# %%
equides['year'] = equides['date'].dt.year

# %%
equides['year'].unique().tolist()
